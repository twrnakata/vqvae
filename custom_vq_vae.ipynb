# %% [markdown]
# # Vector-Quantized Variational Autoencoders
#
# **Author:** [Sayak Paul](https://twitter.com/RisingSayak)<br>
# **Date created:** 2021/07/21<br>
# **Last modified:** 2022/06/27<br>
# **Description:** Training a VQ-VAE for image reconstruction and codebook sampling for generation.

# %% [markdown]
# In this example, we develop a Vector Quantized Variational Autoencoder (VQ-VAE).
# VQ-VAE was proposed in
# [Neural Discrete Representation Learning](https://arxiv.org/abs/1711.00937)
# by van der Oord et al. In standard VAEs, the latent space is continuous and is sampled
# from a Gaussian distribution. It is generally harder to learn such a continuous
# distribution via gradient descent. VQ-VAEs, on the other hand,
# operate on a discrete latent space, making the optimization problem simpler. It does so
# by maintaining a discrete *codebook*. The codebook is developed by
# discretizing the distance between continuous embeddings and the encoded
# outputs. These discrete code words are then fed to the decoder, which is trained
# to generate reconstructed samples.
#
# For an overview of VQ-VAEs, please refer to the original paper and
# [this video explanation](https://www.youtube.com/watch?v=VZFVUrYcig0).
# If you need a refresher on VAEs, you can refer to
# [this book chapter](https://livebook.manning.com/book/deep-learning-with-python-second-edition/chapter-12/).
# VQ-VAEs are one of the main recipes behind [DALL-E](https://openai.com/blog/dall-e/)
# and the idea of a codebook is used in [VQ-GANs](https://arxiv.org/abs/2012.09841).
#
# This example uses implementation details from the
# [official VQ-VAE tutorial](https://github.com/deepmind/sonnet/blob/master/sonnet/examples/vqvae_example.ipynb)
# from DeepMind.
# ## Requirements
# To run this example, you will need TensorFlow 2.5 or higher, as well as
# TensorFlow Probability, which can be installed using the command below.

# %%
# !pip install -q tensorflow-probability

# %% [markdown]
# ## Imports

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import load_img, img_to_array
import tensorflow_probability as tfp
import tensorflow as tf

import glob
import cv2

# %% [markdown]
# ## `VectorQuantizer` layer
#
# First, we implement a custom layer for the vector quantizer, which is the layer in between
# the encoder and decoder. Consider an output from the encoder, with shape `(batch_size, height, width,
# num_filters)`. The vector quantizer will first flatten this output, only keeping the
# `num_filters` dimension intact. So, the shape would become `(batch_size * height * width,
# num_filters)`. The rationale behind this is to treat the total number of filters as the size for
# the latent embeddings.
#
# An embedding table is then initialized to learn a codebook. We measure the L2-normalized
# distance between the flattened encoder outputs and code words of this codebook. We take the
# code that yields the minimum distance, and we apply one-hot encoding to achieve quantization.
# This way, the code yielding the minimum distance to the corresponding encoder output is
# mapped as one and the remaining codes are mapped as zeros.
#
# Since the quantization process is not differentiable, we apply a
# [straight-through estimator](https://www.hassanaskary.com/python/pytorch/deep%20learning/2020/09/19/intuitive-explanation-of-straight-through-estimators.html)
# in between the decoder and the encoder, so that the decoder gradients are directly propagated
# to the encoder. As the encoder and decoder share the same channel space, the decoder gradients are
# still meaningful to the encoder.

# %%
class VectorQuantizer(layers.Layer):
    def __init__(self, num_embeddings, embedding_dim, beta=0.25, **kwargs):
        super().__init__(**kwargs)
        self.embedding_dim = embedding_dim
        self.num_embeddings = num_embeddings

        # The `beta` parameter is best kept between [0.25, 2] as per the paper.
        self.beta = beta

        # Initialize the embeddings which we will quantize.
        w_init = tf.random_uniform_initializer()
        self.embeddings = tf.Variable(
            initial_value=w_init(
                shape=(self.embedding_dim, self.num_embeddings), dtype="float32"
            ),
            trainable=True,
            name="embeddings_vqvae",
        )

    def call(self, x):
        # Calculate the input shape of the inputs and
        # then flatten the inputs keeping `embedding_dim` intact.
        input_shape = tf.shape(x)
        flattened = tf.reshape(x, [-1, self.embedding_dim])

        # Quantization.
        encoding_indices = self.get_code_indices(flattened)
        encodings = tf.one_hot(encoding_indices, self.num_embeddings)
        quantized = tf.matmul(encodings, self.embeddings, transpose_b=True)

        # Reshape the quantized values back to the original input shape
        quantized = tf.reshape(quantized, input_shape)

        # Calculate vector quantization loss and add that to the layer. You can learn more
        # about adding losses to different layers here:
        # https://keras.io/guides/making_new_layers_and_models_via_subclassing/. Check
        # the original paper to get a handle on the formulation of the loss function.
        commitment_loss = tf.reduce_mean((tf.stop_gradient(quantized) - x) ** 2)
        codebook_loss = tf.reduce_mean((quantized - tf.stop_gradient(x)) ** 2)
        self.add_loss(self.beta * commitment_loss + codebook_loss)

        # Straight-through estimator.
        quantized = x + tf.stop_gradient(quantized - x)
        return quantized

    def get_code_indices(self, flattened_inputs):
        # Calculate L2-normalized distance between the inputs and the codes.
        similarity = tf.matmul(flattened_inputs, self.embeddings)
        distances = (
            tf.reduce_sum(flattened_inputs ** 2, axis=1, keepdims=True)
            + tf.reduce_sum(self.embeddings ** 2, axis=0)
            - 2 * similarity
        )

        # Derive the indices for minimum distances.
        encoding_indices = tf.argmin(distances, axis=1)
        return encoding_indices

# %% [markdown]
# **A note on straight-through estimation**:
#
# This line of code does the straight-through estimation part: `quantized = x +
# tf.stop_gradient(quantized - x)`. During backpropagation, `(quantized - x)` won't be
# included in the computation graph and th gradients obtaind for `quantized`
# will be copied for `inputs`. Thanks to [this video](https://youtu.be/VZFVUrYcig0?t=1393)
# for helping me understand this technique.

# %% [markdown]
# ## Encoder and decoder
#
# Now for the encoder and the decoder for the VQ-VAE. We will keep them small so
# that their capacity is a good fit for the MNIST dataset. The implementation of the encoder and
# come from
# [this example](https://keras.io/examples/generative/vae).
#
# Note that activations _other than ReLU_ may not work for the encoder and decoder layers in the
# quantization architecture: Leaky ReLU activated layers, for example, have proven difficult to
# train, resulting in intermittent loss spikes that the model has trouble recovering from.

# %%
def get_encoder(latent_dim=16):
    encoder_inputs = keras.Input(shape=(256, 256, 3))
    x = layers.Conv2D(32, 3, activation="relu", strides=2, padding="same")(
        encoder_inputs
    )
    x = layers.Conv2D(64, 3, activation="relu", strides=2, padding="same")(x)
    encoder_outputs = layers.Conv2D(latent_dim, 1, padding="same")(x)
    return keras.Model(encoder_inputs, encoder_outputs, name="encoder")


def get_decoder(latent_dim=16):
    latent_inputs = keras.Input(shape=get_encoder(latent_dim).output.shape[1:])
    x = layers.Conv2DTranspose(64, 3, activation="relu", strides=2, padding="same")(
        latent_inputs
    )
    x = layers.Conv2DTranspose(32, 3, activation="relu", strides=2, padding="same")(x)
    decoder_outputs = layers.Conv2DTranspose(3, 3, padding="same")(x)
    return keras.Model(latent_inputs, decoder_outputs, name="decoder")

# %% [markdown]
# ## Standalone VQ-VAE model

# %%
def get_vqvae(latent_dim=16, num_embeddings=64):
    vq_layer = VectorQuantizer(num_embeddings, latent_dim, name="vector_quantizer")
    encoder = get_encoder(latent_dim)
    decoder = get_decoder(latent_dim)
    inputs = keras.Input(shape=(256, 256, 3))
    encoder_outputs = encoder(inputs)
    quantized_latents = vq_layer(encoder_outputs)
    reconstructions = decoder(quantized_latents)
    return keras.Model(inputs, reconstructions, name="vq_vae")


get_vqvae().summary()
# Out:
# Model: "vq_vae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_12 (InputLayer)       [(None, 256, 256, 3)]     0
#
#  encoder (Functional)        (None, 64, 64, 16)        20432
#
#  vector_quantizer (VectorQua  (None, 64, 64, 16)       1024
#  ntizer)
#
#  decoder (Functional)        (None, 256, 256, 3)       28611
#
# =================================================================
# Total params: 50,067
# Trainable params: 50,067
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Note that the output channels of the encoder should match the `latent_dim` for the vector
# quantizer.

# %% [markdown]
# ## Wrapping up the training loop inside `VQVAETrainer`

# %%
class VQVAETrainer(keras.models.Model):
    def __init__(self, train_variance, latent_dim=32, num_embeddings=128, **kwargs):
        super(VQVAETrainer, self).__init__(**kwargs)
        self.train_variance = train_variance
        self.latent_dim = latent_dim
        self.num_embeddings = num_embeddings
        
        self.this_losses = []

        self.vqvae = get_vqvae(self.latent_dim, self.num_embeddings)

        self.total_loss_tracker = keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.vq_loss_tracker = keras.metrics.Mean(name="vq_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.vq_loss_tracker,
        ]


    def train_step(self, x):
        with tf.GradientTape() as tape:
            # Outputs from the VQ-VAE.
            reconstructions = self.vqvae(x)

            # Calculate the losses.
            reconstruction_loss = (
                tf.reduce_mean((x - reconstructions) ** 2) / self.train_variance
            )
            total_loss = reconstruction_loss + sum(self.vqvae.losses)

        # Backpropagation.
        grads = tape.gradient(total_loss, self.vqvae.trainable_variables)
        self.optimizer.apply_gradients(zip(grads, self.vqvae.trainable_variables))

        # Loss tracking.
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.vq_loss_tracker.update_state(sum(self.vqvae.losses))

        # Log results.
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "vqvae_loss": self.vq_loss_tracker.result(),
        }

# %% [markdown]
# ## Load and preprocess the MNIST dataset

# %%
dirs = ['/content/drive/MyDrive/Datasets/decade_database/1930s/',
       '/content/drive/MyDrive/Datasets/decade_database/1940s/',
       '/content/drive/MyDrive/Datasets/decade_database/1950s/',
       '/content/drive/MyDrive/Datasets/decade_database/1960s/',
       '/content/drive/MyDrive/Datasets/decade_database/1970s/']

load_datasets = [glob.glob(dir+'*.jpg') for dir in dirs]
datasets = []




for folder in load_datasets:
  for path in folder:
    img = load_img(path)
    img = img.resize((256,256))
    datasets.append(img_to_array(img, dtype=float))

print(len(datasets))
# Out:
# 1325

# %%
datasets = np.array(datasets)

datasets.shape
# Out:
# (1325, 256, 256, 3)

# %%
# (x_train, _), (x_test, _) = keras.datasets.cifar10.load_data()

x_train = datasets

# x_train = np.expand_dims(x_train, -1)
# x_test = np.expand_dims(x_test, -1)
x_train_scaled = (x_train / 255.0) - 0.5
# x_test_scaled = (x_test / 255.0) - 0.5

data_variance = np.var(x_train / 255.0)

print(data_variance)
# Out:
# 0.07720460537390059

# %% [markdown]
# ## Train the VQ-VAE model

# %%
vqvae_trainer = VQVAETrainer(data_variance, latent_dim=16, num_embeddings=128)
vqvae_trainer.compile(optimizer=keras.optimizers.Adam())
vqvae_trainer.fit(x_train_scaled, epochs=2000, batch_size=64)
# Out:
# Epoch 1/2000
# 21/21 [==============================] - 9s 293ms/step - loss: 1.0992 - reconstruction_loss: 0.8741 - vqvae_loss: 0.1111
# Epoch 2/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 8.0956 - reconstruction_loss: 0.4665 - vqvae_loss: 7.5634
# Epoch 3/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 78.0384 - reconstruction_loss: 0.3647 - vqvae_loss: 77.6705
# Epoch 4/2000
# 21/21 [==============================] - 5s 239ms/step - loss: 63.8054 - reconstruction_loss: 0.3587 - vqvae_loss: 63.4483
# Epoch 5/2000
# 21/21 [==============================] - 5s 242ms/step - loss: 30.2285 - reconstruction_loss: 0.3602 - vqvae_loss: 29.8693
# Epoch 6/2000
# 21/21 [==============================] - 5s 242ms/step - loss: 24.5307 - reconstruction_loss: 0.3592 - vqvae_loss: 24.1732
# Epoch 7/2000
# 21/21 [==============================] - 5s 241ms/step - loss: 20.3490 - reconstruction_loss: 0.3691 - vqvae_loss: 19.9841
# Epoch 8/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 16.3679 - reconstruction_loss: 0.3816 - vqvae_loss: 15.9876
# Epoch 9/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 17.0551 - reconstruction_loss: 0.3015 - vqvae_loss: 16.7268
# Epoch 10/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 12.4639 - reconstruction_loss: 0.2558 - vqvae_loss: 12.2143
# Epoch 11/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 7.0848 - reconstruction_loss: 0.2269 - vqvae_loss: 6.8557
# Epoch 12/2000
# 21/21 [==============================] - 5s 230ms/step - loss: 4.1630 - reconstruction_loss: 0.2211 - vqvae_loss: 3.9349
# Epoch 13/2000
# 21/21 [==============================] - 5s 230ms/step - loss: 3.2172 - reconstruction_loss: 0.2237 - vqvae_loss: 2.9968
# Epoch 14/2000
# 21/21 [==============================] - 5s 229ms/step - loss: 2.6535 - reconstruction_loss: 0.2221 - vqvae_loss: 2.4270
# Epoch 15/2000
# 21/21 [==============================] - 5s 230ms/step - loss: 1.9725 - reconstruction_loss: 0.2084 - vqvae_loss: 1.7629
# Epoch 16/2000
# 21/21 [==============================] - 5s 231ms/step - loss: 1.5508 - reconstruction_loss: 0.2067 - vqvae_loss: 1.3445
# Epoch 17/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 1.3842 - reconstruction_loss: 0.1929 - vqvae_loss: 1.1862
# Epoch 18/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 1.1505 - reconstruction_loss: 0.1890 - vqvae_loss: 0.9635
# Epoch 19/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 1.0207 - reconstruction_loss: 0.1935 - vqvae_loss: 0.8295
# Epoch 20/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 2.6561 - reconstruction_loss: 0.1924 - vqvae_loss: 2.4623
# Epoch 21/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 1.6036 - reconstruction_loss: 0.2012 - vqvae_loss: 1.4061
# Epoch 22/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 1.1820 - reconstruction_loss: 0.1907 - vqvae_loss: 0.9911
# Epoch 23/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 1.5854 - reconstruction_loss: 0.1828 - vqvae_loss: 1.4034
# Epoch 24/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 1.3374 - reconstruction_loss: 0.1794 - vqvae_loss: 1.1561
# Epoch 25/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 1.2708 - reconstruction_loss: 0.1746 - vqvae_loss: 1.0949
# Epoch 26/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 1.1104 - reconstruction_loss: 0.1722 - vqvae_loss: 0.9355
# Epoch 27/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 1.1438 - reconstruction_loss: 0.1673 - vqvae_loss: 0.9745
# Epoch 28/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.9833 - reconstruction_loss: 0.1630 - vqvae_loss: 0.8216
# Epoch 29/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.9473 - reconstruction_loss: 0.1581 - vqvae_loss: 0.7874
# Epoch 30/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.8523 - reconstruction_loss: 0.1551 - vqvae_loss: 0.6999
# Epoch 31/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.8196 - reconstruction_loss: 0.1521 - vqvae_loss: 0.6680
# Epoch 32/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.7823 - reconstruction_loss: 0.1501 - vqvae_loss: 0.6315
# Epoch 33/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.7138 - reconstruction_loss: 0.1490 - vqvae_loss: 0.5643
# Epoch 34/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.7029 - reconstruction_loss: 0.1500 - vqvae_loss: 0.5517
# Epoch 35/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.6027 - reconstruction_loss: 0.1500 - vqvae_loss: 0.4518
# Epoch 36/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.6008 - reconstruction_loss: 0.1485 - vqvae_loss: 0.4511
# Epoch 37/2000
# 21/21 [==============================] - 5s 231ms/step - loss: 0.5786 - reconstruction_loss: 0.1481 - vqvae_loss: 0.4321
# Epoch 38/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.5365 - reconstruction_loss: 0.1466 - vqvae_loss: 0.3910
# Epoch 39/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.5404 - reconstruction_loss: 0.1422 - vqvae_loss: 0.3979
# Epoch 40/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.5076 - reconstruction_loss: 0.1399 - vqvae_loss: 0.3664
# Epoch 41/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.4905 - reconstruction_loss: 0.1394 - vqvae_loss: 0.3526
# Epoch 42/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4787 - reconstruction_loss: 0.1373 - vqvae_loss: 0.3405
# Epoch 43/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4564 - reconstruction_loss: 0.1362 - vqvae_loss: 0.3183
# Epoch 44/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4472 - reconstruction_loss: 0.1347 - vqvae_loss: 0.3115
# Epoch 45/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4169 - reconstruction_loss: 0.1324 - vqvae_loss: 0.2849
# Epoch 46/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4387 - reconstruction_loss: 0.1317 - vqvae_loss: 0.3051
# Epoch 47/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4277 - reconstruction_loss: 0.1289 - vqvae_loss: 0.2966
# Epoch 48/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.4125 - reconstruction_loss: 0.1281 - vqvae_loss: 0.2826
# Epoch 49/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.4081 - reconstruction_loss: 0.1281 - vqvae_loss: 0.2781
# Epoch 50/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4020 - reconstruction_loss: 0.1275 - vqvae_loss: 0.2744
# Epoch 51/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.4104 - reconstruction_loss: 0.1274 - vqvae_loss: 0.2821
# Epoch 52/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.4014 - reconstruction_loss: 0.1288 - vqvae_loss: 0.2731
# Epoch 53/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.4023 - reconstruction_loss: 0.1272 - vqvae_loss: 0.2751
# Epoch 54/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.3911 - reconstruction_loss: 0.1253 - vqvae_loss: 0.2648
# Epoch 55/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.3684 - reconstruction_loss: 0.1237 - vqvae_loss: 0.2441
# Epoch 56/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.3599 - reconstruction_loss: 0.1235 - vqvae_loss: 0.2375
# Epoch 57/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.3513 - reconstruction_loss: 0.1223 - vqvae_loss: 0.2290
# Epoch 58/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.3460 - reconstruction_loss: 0.1220 - vqvae_loss: 0.2237
# Epoch 59/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.3432 - reconstruction_loss: 0.1179 - vqvae_loss: 0.2217
# Epoch 60/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.3227 - reconstruction_loss: 0.1147 - vqvae_loss: 0.2069
# Epoch 61/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.3134 - reconstruction_loss: 0.1124 - vqvae_loss: 0.1988
# Epoch 62/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.3034 - reconstruction_loss: 0.1110 - vqvae_loss: 0.1905
# Epoch 63/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2912 - reconstruction_loss: 0.1101 - vqvae_loss: 0.1824
# Epoch 64/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2876 - reconstruction_loss: 0.1095 - vqvae_loss: 0.1779
# Epoch 65/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2786 - reconstruction_loss: 0.1090 - vqvae_loss: 0.1713
# Epoch 66/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2781 - reconstruction_loss: 0.1084 - vqvae_loss: 0.1717
# Epoch 67/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2863 - reconstruction_loss: 0.1078 - vqvae_loss: 0.1763
# Epoch 68/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2833 - reconstruction_loss: 0.1073 - vqvae_loss: 0.1745
# Epoch 69/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2739 - reconstruction_loss: 0.1061 - vqvae_loss: 0.1682
# Epoch 70/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2700 - reconstruction_loss: 0.1057 - vqvae_loss: 0.1651
# Epoch 71/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2695 - reconstruction_loss: 0.1053 - vqvae_loss: 0.1648
# Epoch 72/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2656 - reconstruction_loss: 0.1045 - vqvae_loss: 0.1613
# Epoch 73/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2641 - reconstruction_loss: 0.1038 - vqvae_loss: 0.1612
# Epoch 74/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2634 - reconstruction_loss: 0.1029 - vqvae_loss: 0.1609
# Epoch 75/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2596 - reconstruction_loss: 0.1025 - vqvae_loss: 0.1572
# Epoch 76/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2615 - reconstruction_loss: 0.1019 - vqvae_loss: 0.1586
# Epoch 77/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2571 - reconstruction_loss: 0.1014 - vqvae_loss: 0.1559
# Epoch 78/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2568 - reconstruction_loss: 0.1019 - vqvae_loss: 0.1551
# Epoch 79/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2571 - reconstruction_loss: 0.1003 - vqvae_loss: 0.1549
# Epoch 80/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2482 - reconstruction_loss: 0.0993 - vqvae_loss: 0.1497
# Epoch 81/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2458 - reconstruction_loss: 0.0981 - vqvae_loss: 0.1483
# Epoch 82/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2462 - reconstruction_loss: 0.0976 - vqvae_loss: 0.1471
# Epoch 83/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2413 - reconstruction_loss: 0.0974 - vqvae_loss: 0.1441
# Epoch 84/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2427 - reconstruction_loss: 0.0969 - vqvae_loss: 0.1449
# Epoch 85/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2389 - reconstruction_loss: 0.0966 - vqvae_loss: 0.1436
# Epoch 86/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2407 - reconstruction_loss: 0.0962 - vqvae_loss: 0.1436
# Epoch 87/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2389 - reconstruction_loss: 0.0957 - vqvae_loss: 0.1424
# Epoch 88/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2400 - reconstruction_loss: 0.0956 - vqvae_loss: 0.1436
# Epoch 89/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2408 - reconstruction_loss: 0.0950 - vqvae_loss: 0.1430
# Epoch 90/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2327 - reconstruction_loss: 0.0946 - vqvae_loss: 0.1383
# Epoch 91/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2288 - reconstruction_loss: 0.0944 - vqvae_loss: 0.1350
# Epoch 92/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2274 - reconstruction_loss: 0.0937 - vqvae_loss: 0.1336
# Epoch 93/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2259 - reconstruction_loss: 0.0932 - vqvae_loss: 0.1325
# Epoch 94/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2225 - reconstruction_loss: 0.0927 - vqvae_loss: 0.1306
# Epoch 95/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2237 - reconstruction_loss: 0.0923 - vqvae_loss: 0.1312
# Epoch 96/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2202 - reconstruction_loss: 0.0920 - vqvae_loss: 0.1286
# Epoch 97/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2227 - reconstruction_loss: 0.0918 - vqvae_loss: 0.1303
# Epoch 98/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2212 - reconstruction_loss: 0.0914 - vqvae_loss: 0.1291
# Epoch 99/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2238 - reconstruction_loss: 0.0911 - vqvae_loss: 0.1319
# Epoch 100/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2195 - reconstruction_loss: 0.0908 - vqvae_loss: 0.1285
# Epoch 101/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2151 - reconstruction_loss: 0.0905 - vqvae_loss: 0.1267
# Epoch 102/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2196 - reconstruction_loss: 0.0902 - vqvae_loss: 0.1295
# Epoch 103/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2142 - reconstruction_loss: 0.0901 - vqvae_loss: 0.1252
# Epoch 104/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2145 - reconstruction_loss: 0.0901 - vqvae_loss: 0.1255
# Epoch 105/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2160 - reconstruction_loss: 0.0901 - vqvae_loss: 0.1256
# Epoch 106/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2171 - reconstruction_loss: 0.0893 - vqvae_loss: 0.1268
# Epoch 107/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.2148 - reconstruction_loss: 0.0888 - vqvae_loss: 0.1266
# Epoch 108/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2112 - reconstruction_loss: 0.0882 - vqvae_loss: 0.1234
# Epoch 109/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2096 - reconstruction_loss: 0.0880 - vqvae_loss: 0.1229
# Epoch 110/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2067 - reconstruction_loss: 0.0876 - vqvae_loss: 0.1196
# Epoch 111/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2099 - reconstruction_loss: 0.0869 - vqvae_loss: 0.1223
# Epoch 112/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2055 - reconstruction_loss: 0.0862 - vqvae_loss: 0.1193
# Epoch 113/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1999 - reconstruction_loss: 0.0854 - vqvae_loss: 0.1145
# Epoch 114/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1984 - reconstruction_loss: 0.0849 - vqvae_loss: 0.1133
# Epoch 115/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1919 - reconstruction_loss: 0.0842 - vqvae_loss: 0.1093
# Epoch 116/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1946 - reconstruction_loss: 0.0835 - vqvae_loss: 0.1117
# Epoch 117/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1900 - reconstruction_loss: 0.0831 - vqvae_loss: 0.1069
# Epoch 118/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1846 - reconstruction_loss: 0.0830 - vqvae_loss: 0.1040
# Epoch 119/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1828 - reconstruction_loss: 0.0824 - vqvae_loss: 0.1013
# Epoch 120/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1828 - reconstruction_loss: 0.0821 - vqvae_loss: 0.1005
# Epoch 121/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1827 - reconstruction_loss: 0.0817 - vqvae_loss: 0.1007
# Epoch 122/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1824 - reconstruction_loss: 0.0819 - vqvae_loss: 0.1002
# Epoch 123/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1815 - reconstruction_loss: 0.0815 - vqvae_loss: 0.1001
# Epoch 124/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1772 - reconstruction_loss: 0.0815 - vqvae_loss: 0.0970
# Epoch 125/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1836 - reconstruction_loss: 0.0813 - vqvae_loss: 0.1013
# Epoch 126/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1787 - reconstruction_loss: 0.0810 - vqvae_loss: 0.0985
# Epoch 127/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1799 - reconstruction_loss: 0.0806 - vqvae_loss: 0.0997
# Epoch 128/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1800 - reconstruction_loss: 0.0805 - vqvae_loss: 0.0993
# Epoch 129/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1779 - reconstruction_loss: 0.0802 - vqvae_loss: 0.0973
# Epoch 130/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1730 - reconstruction_loss: 0.0798 - vqvae_loss: 0.0947
# Epoch 131/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1735 - reconstruction_loss: 0.0796 - vqvae_loss: 0.0950
# Epoch 132/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1762 - reconstruction_loss: 0.0796 - vqvae_loss: 0.0965
# Epoch 133/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1744 - reconstruction_loss: 0.0791 - vqvae_loss: 0.0954
# Epoch 134/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1766 - reconstruction_loss: 0.0788 - vqvae_loss: 0.0970
# Epoch 135/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1720 - reconstruction_loss: 0.0789 - vqvae_loss: 0.0935
# Epoch 136/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1746 - reconstruction_loss: 0.0789 - vqvae_loss: 0.0953
# Epoch 137/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1729 - reconstruction_loss: 0.0785 - vqvae_loss: 0.0953
# Epoch 138/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1720 - reconstruction_loss: 0.0786 - vqvae_loss: 0.0940
# Epoch 139/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1742 - reconstruction_loss: 0.0782 - vqvae_loss: 0.0949
# Epoch 140/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1728 - reconstruction_loss: 0.0776 - vqvae_loss: 0.0947
# Epoch 141/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1743 - reconstruction_loss: 0.0775 - vqvae_loss: 0.0960
# Epoch 142/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1750 - reconstruction_loss: 0.0774 - vqvae_loss: 0.0970
# Epoch 143/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1736 - reconstruction_loss: 0.0772 - vqvae_loss: 0.0958
# Epoch 144/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1719 - reconstruction_loss: 0.0772 - vqvae_loss: 0.0946
# Epoch 145/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1685 - reconstruction_loss: 0.0775 - vqvae_loss: 0.0929
# Epoch 146/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1699 - reconstruction_loss: 0.0768 - vqvae_loss: 0.0931
# Epoch 147/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1693 - reconstruction_loss: 0.0766 - vqvae_loss: 0.0939
# Epoch 148/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1708 - reconstruction_loss: 0.0764 - vqvae_loss: 0.0942
# Epoch 149/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1711 - reconstruction_loss: 0.0762 - vqvae_loss: 0.0940
# Epoch 150/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1711 - reconstruction_loss: 0.0759 - vqvae_loss: 0.0950
# Epoch 151/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1739 - reconstruction_loss: 0.0759 - vqvae_loss: 0.0966
# Epoch 152/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1713 - reconstruction_loss: 0.0757 - vqvae_loss: 0.0953
# Epoch 153/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1706 - reconstruction_loss: 0.0758 - vqvae_loss: 0.0951
# Epoch 154/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1733 - reconstruction_loss: 0.0756 - vqvae_loss: 0.0968
# Epoch 155/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1696 - reconstruction_loss: 0.0757 - vqvae_loss: 0.0960
# Epoch 156/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1749 - reconstruction_loss: 0.0755 - vqvae_loss: 0.0995
# Epoch 157/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1784 - reconstruction_loss: 0.0751 - vqvae_loss: 0.1013
# Epoch 158/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1742 - reconstruction_loss: 0.0753 - vqvae_loss: 0.0992
# Epoch 159/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1739 - reconstruction_loss: 0.0752 - vqvae_loss: 0.1003
# Epoch 160/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1777 - reconstruction_loss: 0.0749 - vqvae_loss: 0.1022
# Epoch 161/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1778 - reconstruction_loss: 0.0749 - vqvae_loss: 0.1021
# Epoch 162/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1768 - reconstruction_loss: 0.0746 - vqvae_loss: 0.1013
# Epoch 163/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1789 - reconstruction_loss: 0.0746 - vqvae_loss: 0.1034
# Epoch 164/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1753 - reconstruction_loss: 0.0745 - vqvae_loss: 0.1013
# Epoch 165/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1774 - reconstruction_loss: 0.0743 - vqvae_loss: 0.1030
# Epoch 166/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1767 - reconstruction_loss: 0.0741 - vqvae_loss: 0.1021
# Epoch 167/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1766 - reconstruction_loss: 0.0739 - vqvae_loss: 0.1028
# Epoch 168/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1803 - reconstruction_loss: 0.0740 - vqvae_loss: 0.1053
# Epoch 169/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1764 - reconstruction_loss: 0.0739 - vqvae_loss: 0.1030
# Epoch 170/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1773 - reconstruction_loss: 0.0738 - vqvae_loss: 0.1037
# Epoch 171/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1771 - reconstruction_loss: 0.0737 - vqvae_loss: 0.1041
# Epoch 172/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1777 - reconstruction_loss: 0.0734 - vqvae_loss: 0.1040
# Epoch 173/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1807 - reconstruction_loss: 0.0734 - vqvae_loss: 0.1055
# Epoch 174/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1810 - reconstruction_loss: 0.0734 - vqvae_loss: 0.1058
# Epoch 175/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1750 - reconstruction_loss: 0.0732 - vqvae_loss: 0.1023
# Epoch 176/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1761 - reconstruction_loss: 0.0731 - vqvae_loss: 0.1033
# Epoch 177/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1785 - reconstruction_loss: 0.0730 - vqvae_loss: 0.1049
# Epoch 178/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1816 - reconstruction_loss: 0.0729 - vqvae_loss: 0.1070
# Epoch 179/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1785 - reconstruction_loss: 0.0726 - vqvae_loss: 0.1052
# Epoch 180/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1766 - reconstruction_loss: 0.0727 - vqvae_loss: 0.1042
# Epoch 181/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1781 - reconstruction_loss: 0.0725 - vqvae_loss: 0.1057
# Epoch 182/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1796 - reconstruction_loss: 0.0724 - vqvae_loss: 0.1078
# Epoch 183/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1798 - reconstruction_loss: 0.0721 - vqvae_loss: 0.1066
# Epoch 184/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1794 - reconstruction_loss: 0.0724 - vqvae_loss: 0.1064
# Epoch 185/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1785 - reconstruction_loss: 0.0723 - vqvae_loss: 0.1067
# Epoch 186/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1804 - reconstruction_loss: 0.0724 - vqvae_loss: 0.1075
# Epoch 187/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1757 - reconstruction_loss: 0.0719 - vqvae_loss: 0.1044
# Epoch 188/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1732 - reconstruction_loss: 0.0719 - vqvae_loss: 0.1034
# Epoch 189/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1744 - reconstruction_loss: 0.0717 - vqvae_loss: 0.1042
# Epoch 190/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1784 - reconstruction_loss: 0.0715 - vqvae_loss: 0.1070
# Epoch 191/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1778 - reconstruction_loss: 0.0716 - vqvae_loss: 0.1062
# Epoch 192/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1771 - reconstruction_loss: 0.0717 - vqvae_loss: 0.1057
# Epoch 193/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1804 - reconstruction_loss: 0.0717 - vqvae_loss: 0.1074
# Epoch 194/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1793 - reconstruction_loss: 0.0713 - vqvae_loss: 0.1068
# Epoch 195/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1778 - reconstruction_loss: 0.0709 - vqvae_loss: 0.1068
# Epoch 196/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1784 - reconstruction_loss: 0.0709 - vqvae_loss: 0.1071
# Epoch 197/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1799 - reconstruction_loss: 0.0709 - vqvae_loss: 0.1075
# Epoch 198/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1791 - reconstruction_loss: 0.0708 - vqvae_loss: 0.1080
# Epoch 199/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1777 - reconstruction_loss: 0.0706 - vqvae_loss: 0.1070
# Epoch 200/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1768 - reconstruction_loss: 0.0707 - vqvae_loss: 0.1061
# Epoch 201/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1787 - reconstruction_loss: 0.0709 - vqvae_loss: 0.1080
# Epoch 202/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1810 - reconstruction_loss: 0.0705 - vqvae_loss: 0.1095
# Epoch 203/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1774 - reconstruction_loss: 0.0704 - vqvae_loss: 0.1065
# Epoch 204/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1772 - reconstruction_loss: 0.0704 - vqvae_loss: 0.1067
# Epoch 205/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1759 - reconstruction_loss: 0.0702 - vqvae_loss: 0.1066
# Epoch 206/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1764 - reconstruction_loss: 0.0703 - vqvae_loss: 0.1059
# Epoch 207/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1802 - reconstruction_loss: 0.0702 - vqvae_loss: 0.1083
# Epoch 208/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1772 - reconstruction_loss: 0.0699 - vqvae_loss: 0.1066
# Epoch 209/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1763 - reconstruction_loss: 0.0698 - vqvae_loss: 0.1071
# Epoch 210/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1751 - reconstruction_loss: 0.0698 - vqvae_loss: 0.1058
# Epoch 211/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1754 - reconstruction_loss: 0.0697 - vqvae_loss: 0.1060
# Epoch 212/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1743 - reconstruction_loss: 0.0694 - vqvae_loss: 0.1057
# Epoch 213/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1770 - reconstruction_loss: 0.0694 - vqvae_loss: 0.1071
# Epoch 214/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1761 - reconstruction_loss: 0.0694 - vqvae_loss: 0.1062
# Epoch 215/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1761 - reconstruction_loss: 0.0691 - vqvae_loss: 0.1075
# Epoch 216/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1747 - reconstruction_loss: 0.0689 - vqvae_loss: 0.1057
# Epoch 217/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1766 - reconstruction_loss: 0.0691 - vqvae_loss: 0.1072
# Epoch 218/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1768 - reconstruction_loss: 0.0687 - vqvae_loss: 0.1075
# Epoch 219/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1766 - reconstruction_loss: 0.0686 - vqvae_loss: 0.1070
# Epoch 220/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1733 - reconstruction_loss: 0.0690 - vqvae_loss: 0.1055
# Epoch 221/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1785 - reconstruction_loss: 0.0686 - vqvae_loss: 0.1084
# Epoch 222/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1743 - reconstruction_loss: 0.0682 - vqvae_loss: 0.1064
# Epoch 223/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1732 - reconstruction_loss: 0.0682 - vqvae_loss: 0.1057
# Epoch 224/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1764 - reconstruction_loss: 0.0680 - vqvae_loss: 0.1079
# Epoch 225/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1764 - reconstruction_loss: 0.0680 - vqvae_loss: 0.1075
# Epoch 226/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1739 - reconstruction_loss: 0.0676 - vqvae_loss: 0.1064
# Epoch 227/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1733 - reconstruction_loss: 0.0679 - vqvae_loss: 0.1062
# Epoch 228/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1726 - reconstruction_loss: 0.0677 - vqvae_loss: 0.1057
# Epoch 229/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1723 - reconstruction_loss: 0.0678 - vqvae_loss: 0.1053
# Epoch 230/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1766 - reconstruction_loss: 0.0674 - vqvae_loss: 0.1085
# Epoch 231/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1755 - reconstruction_loss: 0.0672 - vqvae_loss: 0.1073
# Epoch 232/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1732 - reconstruction_loss: 0.0672 - vqvae_loss: 0.1064
# Epoch 233/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1740 - reconstruction_loss: 0.0672 - vqvae_loss: 0.1069
# Epoch 234/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1743 - reconstruction_loss: 0.0670 - vqvae_loss: 0.1069
# Epoch 235/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1725 - reconstruction_loss: 0.0668 - vqvae_loss: 0.1071
# Epoch 236/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1725 - reconstruction_loss: 0.0667 - vqvae_loss: 0.1062
# Epoch 237/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1783 - reconstruction_loss: 0.0665 - vqvae_loss: 0.1095
# Epoch 238/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1785 - reconstruction_loss: 0.0667 - vqvae_loss: 0.1111
# Epoch 239/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1749 - reconstruction_loss: 0.0666 - vqvae_loss: 0.1082
# Epoch 240/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1727 - reconstruction_loss: 0.0665 - vqvae_loss: 0.1073
# Epoch 241/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1751 - reconstruction_loss: 0.0665 - vqvae_loss: 0.1079
# Epoch 242/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1733 - reconstruction_loss: 0.0663 - vqvae_loss: 0.1079
# Epoch 243/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1772 - reconstruction_loss: 0.0664 - vqvae_loss: 0.1097
# Epoch 244/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1755 - reconstruction_loss: 0.0661 - vqvae_loss: 0.1094
# Epoch 245/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1757 - reconstruction_loss: 0.0661 - vqvae_loss: 0.1100
# Epoch 246/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1777 - reconstruction_loss: 0.0658 - vqvae_loss: 0.1107
# Epoch 247/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1757 - reconstruction_loss: 0.0657 - vqvae_loss: 0.1104
# Epoch 248/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1764 - reconstruction_loss: 0.0657 - vqvae_loss: 0.1104
# Epoch 249/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1755 - reconstruction_loss: 0.0657 - vqvae_loss: 0.1101
# Epoch 250/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1759 - reconstruction_loss: 0.0656 - vqvae_loss: 0.1105
# Epoch 251/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1768 - reconstruction_loss: 0.0654 - vqvae_loss: 0.1114
# Epoch 252/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1787 - reconstruction_loss: 0.0652 - vqvae_loss: 0.1130
# Epoch 253/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1798 - reconstruction_loss: 0.0651 - vqvae_loss: 0.1141
# Epoch 254/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1788 - reconstruction_loss: 0.0650 - vqvae_loss: 0.1137
# Epoch 255/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1769 - reconstruction_loss: 0.0651 - vqvae_loss: 0.1128
# Epoch 256/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1823 - reconstruction_loss: 0.0649 - vqvae_loss: 0.1169
# Epoch 257/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1820 - reconstruction_loss: 0.0648 - vqvae_loss: 0.1167
# Epoch 258/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1772 - reconstruction_loss: 0.0645 - vqvae_loss: 0.1134
# Epoch 259/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1779 - reconstruction_loss: 0.0647 - vqvae_loss: 0.1137
# Epoch 260/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1795 - reconstruction_loss: 0.0648 - vqvae_loss: 0.1150
# Epoch 261/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1817 - reconstruction_loss: 0.0641 - vqvae_loss: 0.1162
# Epoch 262/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1765 - reconstruction_loss: 0.0641 - vqvae_loss: 0.1136
# Epoch 263/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1792 - reconstruction_loss: 0.0640 - vqvae_loss: 0.1152
# Epoch 264/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1749 - reconstruction_loss: 0.0639 - vqvae_loss: 0.1122
# Epoch 265/2000
# 21/21 [==============================] - 5s 232ms/step - loss: 0.1770 - reconstruction_loss: 0.0636 - vqvae_loss: 0.1135
# Epoch 266/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1793 - reconstruction_loss: 0.0636 - vqvae_loss: 0.1154
# Epoch 267/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1782 - reconstruction_loss: 0.0634 - vqvae_loss: 0.1147
# Epoch 268/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1776 - reconstruction_loss: 0.0635 - vqvae_loss: 0.1141
# Epoch 269/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1765 - reconstruction_loss: 0.0631 - vqvae_loss: 0.1140
# Epoch 270/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1786 - reconstruction_loss: 0.0631 - vqvae_loss: 0.1150
# Epoch 271/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1754 - reconstruction_loss: 0.0632 - vqvae_loss: 0.1127
# Epoch 272/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1774 - reconstruction_loss: 0.0628 - vqvae_loss: 0.1144
# Epoch 273/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1766 - reconstruction_loss: 0.0628 - vqvae_loss: 0.1138
# Epoch 274/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1746 - reconstruction_loss: 0.0629 - vqvae_loss: 0.1130
# Epoch 275/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1771 - reconstruction_loss: 0.0625 - vqvae_loss: 0.1141
# Epoch 276/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1768 - reconstruction_loss: 0.0624 - vqvae_loss: 0.1138
# Epoch 277/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1793 - reconstruction_loss: 0.0625 - vqvae_loss: 0.1157
# Epoch 278/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1768 - reconstruction_loss: 0.0623 - vqvae_loss: 0.1141
# Epoch 279/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1759 - reconstruction_loss: 0.0620 - vqvae_loss: 0.1137
# Epoch 280/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1774 - reconstruction_loss: 0.0617 - vqvae_loss: 0.1151
# Epoch 281/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1742 - reconstruction_loss: 0.0620 - vqvae_loss: 0.1123
# Epoch 282/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1742 - reconstruction_loss: 0.0617 - vqvae_loss: 0.1124
# Epoch 283/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1755 - reconstruction_loss: 0.0614 - vqvae_loss: 0.1134
# Epoch 284/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1725 - reconstruction_loss: 0.0617 - vqvae_loss: 0.1117
# Epoch 285/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1728 - reconstruction_loss: 0.0613 - vqvae_loss: 0.1116
# Epoch 286/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1754 - reconstruction_loss: 0.0612 - vqvae_loss: 0.1133
# Epoch 287/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1715 - reconstruction_loss: 0.0609 - vqvae_loss: 0.1109
# Epoch 288/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1716 - reconstruction_loss: 0.0610 - vqvae_loss: 0.1111
# Epoch 289/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1708 - reconstruction_loss: 0.0608 - vqvae_loss: 0.1111
# Epoch 290/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1733 - reconstruction_loss: 0.0608 - vqvae_loss: 0.1124
# Epoch 291/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1751 - reconstruction_loss: 0.0605 - vqvae_loss: 0.1141
# Epoch 292/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1732 - reconstruction_loss: 0.0604 - vqvae_loss: 0.1128
# Epoch 293/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1744 - reconstruction_loss: 0.0603 - vqvae_loss: 0.1137
# Epoch 294/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1718 - reconstruction_loss: 0.0602 - vqvae_loss: 0.1114
# Epoch 295/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1719 - reconstruction_loss: 0.0604 - vqvae_loss: 0.1121
# Epoch 296/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1716 - reconstruction_loss: 0.0601 - vqvae_loss: 0.1118
# Epoch 297/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1747 - reconstruction_loss: 0.0601 - vqvae_loss: 0.1144
# Epoch 298/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1754 - reconstruction_loss: 0.0598 - vqvae_loss: 0.1146
# Epoch 299/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1730 - reconstruction_loss: 0.0599 - vqvae_loss: 0.1130
# Epoch 300/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1738 - reconstruction_loss: 0.0598 - vqvae_loss: 0.1138
# Epoch 301/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1740 - reconstruction_loss: 0.0597 - vqvae_loss: 0.1142
# Epoch 302/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1737 - reconstruction_loss: 0.0595 - vqvae_loss: 0.1141
# Epoch 303/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1750 - reconstruction_loss: 0.0594 - vqvae_loss: 0.1151
# Epoch 304/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1743 - reconstruction_loss: 0.0593 - vqvae_loss: 0.1152
# Epoch 305/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1750 - reconstruction_loss: 0.0592 - vqvae_loss: 0.1155
# Epoch 306/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1731 - reconstruction_loss: 0.0593 - vqvae_loss: 0.1144
# Epoch 307/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1727 - reconstruction_loss: 0.0592 - vqvae_loss: 0.1139
# Epoch 308/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1753 - reconstruction_loss: 0.0591 - vqvae_loss: 0.1158
# Epoch 309/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1747 - reconstruction_loss: 0.0589 - vqvae_loss: 0.1157
# Epoch 310/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1766 - reconstruction_loss: 0.0588 - vqvae_loss: 0.1173
# Epoch 311/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1724 - reconstruction_loss: 0.0588 - vqvae_loss: 0.1144
# Epoch 312/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1754 - reconstruction_loss: 0.0585 - vqvae_loss: 0.1165
# Epoch 313/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1759 - reconstruction_loss: 0.0586 - vqvae_loss: 0.1176
# Epoch 314/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1722 - reconstruction_loss: 0.0584 - vqvae_loss: 0.1150
# Epoch 315/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1754 - reconstruction_loss: 0.0585 - vqvae_loss: 0.1169
# Epoch 316/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1780 - reconstruction_loss: 0.0584 - vqvae_loss: 0.1187
# Epoch 317/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1781 - reconstruction_loss: 0.0583 - vqvae_loss: 0.1189
# Epoch 318/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1795 - reconstruction_loss: 0.0582 - vqvae_loss: 0.1200
# Epoch 319/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1762 - reconstruction_loss: 0.0580 - vqvae_loss: 0.1184
# Epoch 320/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1735 - reconstruction_loss: 0.0581 - vqvae_loss: 0.1159
# Epoch 321/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1747 - reconstruction_loss: 0.0579 - vqvae_loss: 0.1169
# Epoch 322/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1762 - reconstruction_loss: 0.0580 - vqvae_loss: 0.1185
# Epoch 323/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1747 - reconstruction_loss: 0.0578 - vqvae_loss: 0.1172
# Epoch 324/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1770 - reconstruction_loss: 0.0574 - vqvae_loss: 0.1192
# Epoch 325/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1733 - reconstruction_loss: 0.0576 - vqvae_loss: 0.1165
# Epoch 326/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1768 - reconstruction_loss: 0.0577 - vqvae_loss: 0.1190
# Epoch 327/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1756 - reconstruction_loss: 0.0573 - vqvae_loss: 0.1181
# Epoch 328/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1736 - reconstruction_loss: 0.0573 - vqvae_loss: 0.1177
# Epoch 329/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1765 - reconstruction_loss: 0.0572 - vqvae_loss: 0.1194
# Epoch 330/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1748 - reconstruction_loss: 0.0570 - vqvae_loss: 0.1182
# Epoch 331/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1736 - reconstruction_loss: 0.0570 - vqvae_loss: 0.1175
# Epoch 332/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1767 - reconstruction_loss: 0.0570 - vqvae_loss: 0.1196
# Epoch 333/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1772 - reconstruction_loss: 0.0569 - vqvae_loss: 0.1201
# Epoch 334/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1797 - reconstruction_loss: 0.0569 - vqvae_loss: 0.1214
# Epoch 335/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1754 - reconstruction_loss: 0.0568 - vqvae_loss: 0.1187
# Epoch 336/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1768 - reconstruction_loss: 0.0568 - vqvae_loss: 0.1199
# Epoch 337/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1749 - reconstruction_loss: 0.0567 - vqvae_loss: 0.1188
# Epoch 338/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1743 - reconstruction_loss: 0.0566 - vqvae_loss: 0.1179
# Epoch 339/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1769 - reconstruction_loss: 0.0564 - vqvae_loss: 0.1202
# Epoch 340/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1734 - reconstruction_loss: 0.0563 - vqvae_loss: 0.1178
# Epoch 341/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1783 - reconstruction_loss: 0.0563 - vqvae_loss: 0.1215
# Epoch 342/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.1776 - reconstruction_loss: 0.0563 - vqvae_loss: 0.1215
# Epoch 343/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1759 - reconstruction_loss: 0.0562 - vqvae_loss: 0.1196
# Epoch 344/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1784 - reconstruction_loss: 0.0562 - vqvae_loss: 0.1214
# Epoch 345/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1764 - reconstruction_loss: 0.0560 - vqvae_loss: 0.1205
# Epoch 346/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1780 - reconstruction_loss: 0.0560 - vqvae_loss: 0.1210
# Epoch 347/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.1774 - reconstruction_loss: 0.0559 - vqvae_loss: 0.1207
# Epoch 348/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1752 - reconstruction_loss: 0.0559 - vqvae_loss: 0.1200
# Epoch 349/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1757 - reconstruction_loss: 0.0559 - vqvae_loss: 0.1200
# Epoch 350/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1759 - reconstruction_loss: 0.0558 - vqvae_loss: 0.1201
# Epoch 351/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1792 - reconstruction_loss: 0.0557 - vqvae_loss: 0.1227
# Epoch 352/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.1737 - reconstruction_loss: 0.0558 - vqvae_loss: 0.1187
# Epoch 353/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.1754 - reconstruction_loss: 0.0556 - vqvae_loss: 0.1203
# Epoch 354/2000
# ...
# Epoch 1885/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2112 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1623
# Epoch 1886/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2152 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1655
# Epoch 1887/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2114 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1623
# Epoch 1888/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2124 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1630
# Epoch 1889/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2154 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1653
# Epoch 1890/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2103 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1613
# Epoch 1891/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2126 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1633
# Epoch 1892/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2112 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1622
# Epoch 1893/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2167 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1662
# Epoch 1894/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2124 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1630
# Epoch 1895/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2111 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1619
# Epoch 1896/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2116 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1624
# Epoch 1897/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2100 - reconstruction_loss: 0.0495 - vqvae_loss: 0.1612
# Epoch 1898/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2093 - reconstruction_loss: 0.0496 - vqvae_loss: 0.1605
# Epoch 1899/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2149 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1649
# Epoch 1900/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2128 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1634
# Epoch 1901/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2122 - reconstruction_loss: 0.0495 - vqvae_loss: 0.1624
# Epoch 1902/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2069 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1588
# Epoch 1903/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2084 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1600
# Epoch 1904/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2127 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1632
# Epoch 1905/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2097 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1611
# Epoch 1906/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2107 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1619
# Epoch 1907/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2079 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1598
# Epoch 1908/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2110 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1619
# Epoch 1909/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2103 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1611
# Epoch 1910/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2123 - reconstruction_loss: 0.0495 - vqvae_loss: 0.1628
# Epoch 1911/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2111 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1616
# Epoch 1912/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2128 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1633
# Epoch 1913/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2186 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1679
# Epoch 1914/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2129 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1635
# Epoch 1915/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2119 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1625
# Epoch 1916/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2101 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1612
# Epoch 1917/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2107 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1617
# Epoch 1918/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2089 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1607
# Epoch 1919/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2115 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1627
# Epoch 1920/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2146 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1648
# Epoch 1921/2000
# 21/21 [==============================] - 5s 233ms/step - loss: 0.2170 - reconstruction_loss: 0.0495 - vqvae_loss: 0.1666
# Epoch 1922/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2095 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1610
# Epoch 1923/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2072 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1591
# Epoch 1924/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2154 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1652
# Epoch 1925/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2103 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1614
# Epoch 1926/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2107 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1622
# Epoch 1927/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2146 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1647
# Epoch 1928/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2102 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1614
# Epoch 1929/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2135 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1636
# Epoch 1930/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2117 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1627
# Epoch 1931/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2140 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1642
# Epoch 1932/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2114 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1622
# Epoch 1933/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2127 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1632
# Epoch 1934/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2149 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1646
# Epoch 1935/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2136 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1641
# Epoch 1936/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2096 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1610
# Epoch 1937/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2130 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1636
# Epoch 1938/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2151 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1652
# Epoch 1939/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2124 - reconstruction_loss: 0.0495 - vqvae_loss: 0.1630
# Epoch 1940/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2118 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1625
# Epoch 1941/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2146 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1648
# Epoch 1942/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2120 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1631
# Epoch 1943/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2123 - reconstruction_loss: 0.0495 - vqvae_loss: 0.1627
# Epoch 1944/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2095 - reconstruction_loss: 0.0496 - vqvae_loss: 0.1605
# Epoch 1945/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2157 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1655
# Epoch 1946/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2163 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1660
# Epoch 1947/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2072 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1589
# Epoch 1948/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2109 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1621
# Epoch 1949/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2136 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1638
# Epoch 1950/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2132 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1641
# Epoch 1951/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2118 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1628
# Epoch 1952/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2143 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1648
# Epoch 1953/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2139 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1643
# Epoch 1954/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2092 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1606
# Epoch 1955/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2114 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1623
# Epoch 1956/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2108 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1619
# Epoch 1957/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2181 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1675
# Epoch 1958/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2097 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1608
# Epoch 1959/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2136 - reconstruction_loss: 0.0491 - vqvae_loss: 0.1642
# Epoch 1960/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2137 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1642
# Epoch 1961/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2109 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1617
# Epoch 1962/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2176 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1671
# Epoch 1963/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2099 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1615
# Epoch 1964/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2102 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1613
# Epoch 1965/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2120 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1631
# Epoch 1966/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2122 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1629
# Epoch 1967/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2102 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1616
# Epoch 1968/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2123 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1634
# Epoch 1969/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2153 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1655
# Epoch 1970/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2104 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1617
# Epoch 1971/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2125 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1630
# Epoch 1972/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2092 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1609
# Epoch 1973/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2141 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1641
# Epoch 1974/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2137 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1639
# Epoch 1975/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2145 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1646
# Epoch 1976/2000
# 21/21 [==============================] - 5s 237ms/step - loss: 0.2108 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1619
# Epoch 1977/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2087 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1602
# Epoch 1978/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2090 - reconstruction_loss: 0.0491 - vqvae_loss: 0.1609
# Epoch 1979/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2120 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1626
# Epoch 1980/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2128 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1633
# Epoch 1981/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2124 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1631
# Epoch 1982/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2106 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1618
# Epoch 1983/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2119 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1627
# Epoch 1984/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2099 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1611
# Epoch 1985/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2155 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1653
# Epoch 1986/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2108 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1619
# Epoch 1987/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2101 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1612
# Epoch 1988/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2168 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1668
# Epoch 1989/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2158 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1657
# Epoch 1990/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2130 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1634
# Epoch 1991/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2095 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1609
# Epoch 1992/2000
# 21/21 [==============================] - 5s 235ms/step - loss: 0.2105 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1617
# Epoch 1993/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2097 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1609
# Epoch 1994/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2111 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1619
# Epoch 1995/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2096 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1612
# Epoch 1996/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2123 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1630
# Epoch 1997/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2122 - reconstruction_loss: 0.0493 - vqvae_loss: 0.1630
# Epoch 1998/2000
# 21/21 [==============================] - 5s 236ms/step - loss: 0.2107 - reconstruction_loss: 0.0494 - vqvae_loss: 0.1615
# Epoch 1999/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2119 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1629
# Epoch 2000/2000
# 21/21 [==============================] - 5s 234ms/step - loss: 0.2116 - reconstruction_loss: 0.0492 - vqvae_loss: 0.1623

# %%
def show_subplot(original, reconstructed):
    plt.subplot(1, 2, 1)
    plt.imshow(original.squeeze() + 0.5)
    plt.title("Original")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(reconstructed.squeeze() + 0.5)
    plt.title("Reconstructed")
    plt.axis("off")

    plt.show()


trained_vqvae_model = vqvae_trainer.vqvae
idx = np.random.choice(len(x_train_scaled), 10)
test_images = x_train_scaled[idx]
reconstructions_test = trained_vqvae_model.predict(test_images)

for test_image, reconstructed_image in zip(test_images, reconstructions_test):
    show_subplot(test_image, reconstructed_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
trained_vqvae_model.save('vq_vae_model.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-30-ea87df4dd674> in <module>()
# ----> 1 trained_vqvae_model.save('vq_vae_model.h5')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in get_config(self)
#     774                       "arg2": self.arg2,
#     775                   }})
# --> 776                   return config"""))
#     777
#     778     return config
#
# NotImplementedError:
# Layer VectorQuantizer has arguments ['self', 'num_embeddings', 'embedding_dim', 'beta']
# in `__init__` and therefore must override `get_config()`.
#
# Example:
#
# class CustomLayer(keras.layers.Layer):
#     def __init__(self, arg1, arg2):
#         super().__init__()
#         self.arg1 = arg1
#         self.arg2 = arg2
#
#     def get_config(self):
#         config = super().get_config()
#         config.update({
#             "arg1": self.arg1,
#             "arg2": self.arg2,
#         })
#         return config

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# These results look decent. You are encouraged to play with different hyperparameters
# (especially the number of embeddings and the dimensions of the embeddings) and observe how
# they affect the results.

# %% [markdown]
# ## Visualizing the discrete codes

# %%
encoder = vqvae_trainer.vqvae.get_layer("encoder")
quantizer = vqvae_trainer.vqvae.get_layer("vector_quantizer")

encoded_outputs = encoder.predict(test_images)
flat_enc_outputs = encoded_outputs.reshape(-1, encoded_outputs.shape[-1])
codebook_indices = quantizer.get_code_indices(flat_enc_outputs)
codebook_indices = codebook_indices.numpy().reshape(encoded_outputs.shape[:-1])

for i in range(len(test_images)):
    plt.subplot(1, 2, 1)
    plt.imshow(test_images[i].squeeze() + 0.5)
    plt.title("Original")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(codebook_indices[i])
    plt.title("Code")
    plt.axis("off")
    plt.show()

# %% [markdown]
# The figure above shows that the discrete codes have been able to capture some
# regularities from the dataset. Now, how do we sample from this codebook to create
# novel images? Since these codes are discrete and we imposed a categorical distribution
# on them, we cannot use them yet to generate anything meaningful until we can generate likely
# sequences of codes that we can give to the decoder.
#
# The authors use a PixelCNN to train these codes so that they can be used as powerful priors to
# generate novel examples. PixelCNN was proposed in
# [Conditional Image Generation with PixelCNN Decoders](https://arxiv.org/abs/1606.05328)
# by van der Oord et al. We borrow the implementation from
# [this PixelCNN example](https://keras.io/examples/generative/pixelcnn/). It's an auto-regressive
# generative model where the outputs are conditional on the prior ones. In other words, a PixelCNN
# generates an image on a pixel-by-pixel basis. For the purpose in this example, however, its task
# is to generate code book indices instead of pixels directly. The trained VQ-VAE decoder is used
# to map the indices generated by the PixelCNN back into the pixel space.

# %% [markdown]
# ## PixelCNN hyperparameters

# %%
num_residual_blocks = 2
num_pixelcnn_layers = 2
pixelcnn_input_shape = encoded_outputs.shape[1:-1]
print(f"Input shape of the PixelCNN: {pixelcnn_input_shape}")

# %% [markdown]
# This input shape represents the reduction in the resolution performed by the encoder. With "same" padding,
# this exactly halves the "resolution" of the output shape for each stride-2 convolution layer. So, with these
# two layers, we end up with an encoder output tensor of 7x7 on axes 2 and 3, with the first axis as the batch
# size and the last axis being the code book embedding size. Since the quantization layer in the autoencoder
# maps these 7x7 tensors to indices of the code book, these output layer axis sizes must be matched by the
# PixelCNN as the input shape. The task of the PixelCNN for this architecture is to generate _likely_ 7x7
# arrangements of codebook indices.
#
# Note that this shape is something to optimize for in larger-sized image domains, along with the code
# book sizes. Since the PixelCNN is autoregressive, it needs to pass over each codebook index sequentially
# in order to generate novel images from the codebook. Each stride-2 (or rather more correctly a
# stride (2, 2)) convolution layer will divide the image generation time by four. Note, however, that there
# is probably a lower bound on this part: when the number of codes for the image to reconstruct is too small,
# it has insufficient information for the decoder to represent the level of detail in the image, so the
# output quality will suffer. This can be amended at least to some extent by using a larger code book.
# Since the autoregressive part of the image generation procedure uses codebook indices, there is far less of
# a performance penalty on using a larger code book as the lookup time for a larger-sized code from a larger
# code book is much smaller in comparison to iterating over a larger sequence of code book indices, although
# the size of the code book does impact on the batch size that can pass through the image generation procedure.
# Finding the sweet spot for this trade-off can require some architecture tweaking and could very well differ
# per dataset.

# %% [markdown]
# ## PixelCNN model
#
# Majority of this comes from
# [this example](https://keras.io/examples/generative/pixelcnn/).
#
# ## Notes
# Thanks to [Rein van 't Veer](https://github.com/reinvantveer) for improving this example with
# copy-edits and minor code clean-ups.

# %%
# The first layer is the PixelCNN layer. This layer simply
# builds on the 2D convolutional layer, but includes masking.
class PixelConvLayer(layers.Layer):
    def __init__(self, mask_type, **kwargs):
        super(PixelConvLayer, self).__init__()
        self.mask_type = mask_type
        self.conv = layers.Conv2D(**kwargs)

    def build(self, input_shape):
        # Build the conv2d layer to initialize kernel variables
        self.conv.build(input_shape)
        # Use the initialized kernel to create the mask
        kernel_shape = self.conv.kernel.get_shape()
        self.mask = np.zeros(shape=kernel_shape)
        self.mask[: kernel_shape[0] // 2, ...] = 1.0
        self.mask[kernel_shape[0] // 2, : kernel_shape[1] // 2, ...] = 1.0
        if self.mask_type == "B":
            self.mask[kernel_shape[0] // 2, kernel_shape[1] // 2, ...] = 1.0

    def call(self, inputs):
        self.conv.kernel.assign(self.conv.kernel * self.mask)
        return self.conv(inputs)


# Next, we build our residual block layer.
# This is just a normal residual block, but based on the PixelConvLayer.
class ResidualBlock(keras.layers.Layer):
    def __init__(self, filters, **kwargs):
        super(ResidualBlock, self).__init__(**kwargs)
        self.conv1 = keras.layers.Conv2D(
            filters=filters, kernel_size=1, activation="relu"
        )
        self.pixel_conv = PixelConvLayer(
            mask_type="B",
            filters=filters // 2,
            kernel_size=3,
            activation="relu",
            padding="same",
        )
        self.conv2 = keras.layers.Conv2D(
            filters=filters, kernel_size=1, activation="relu"
        )

    def call(self, inputs):
        x = self.conv1(inputs)
        x = self.pixel_conv(x)
        x = self.conv2(x)
        return keras.layers.add([inputs, x])


pixelcnn_inputs = keras.Input(shape=pixelcnn_input_shape, dtype=tf.int32)
ohe = tf.one_hot(pixelcnn_inputs, vqvae_trainer.num_embeddings)
x = PixelConvLayer(
    mask_type="A", filters=128, kernel_size=7, activation="relu", padding="same"
)(ohe)

for _ in range(num_residual_blocks):
    x = ResidualBlock(filters=128)(x)

for _ in range(num_pixelcnn_layers):
    x = PixelConvLayer(
        mask_type="B",
        filters=128,
        kernel_size=1,
        strides=1,
        activation="relu",
        padding="valid",
    )(x)

out = keras.layers.Conv2D(
    filters=vqvae_trainer.num_embeddings, kernel_size=1, strides=1, padding="valid"
)(x)

pixel_cnn = keras.Model(pixelcnn_inputs, out, name="pixel_cnn")
pixel_cnn.summary()

# %% [markdown]
# ## Prepare data to train the PixelCNN
#
# We will train the PixelCNN to learn a categorical distribution of the discrete codes.
# First, we will generate code indices using the encoder and vector quantizer we just
# trained. Our training objective will be to minimize the crossentropy loss between these
# indices and the PixelCNN outputs. Here, the number of categories is equal to the number
# of embeddings present in our codebook (128 in our case). The PixelCNN model is
# trained to learn a distribution (as opposed to minimizing the L1/L2 loss), which is where
# it gets its generative capabilities from.

# %%
# Generate the codebook indices.
encoded_outputs = encoder.predict(x_train_scaled)
flat_enc_outputs = encoded_outputs.reshape(-1, encoded_outputs.shape[-1])
codebook_indices = quantizer.get_code_indices(flat_enc_outputs)

codebook_indices = codebook_indices.numpy().reshape(encoded_outputs.shape[:-1])
print(f"Shape of the training data for PixelCNN: {codebook_indices.shape}")

# %% [markdown]
# ## PixelCNN training

# %%
pixel_cnn.compile(
    optimizer=keras.optimizers.Adam(3e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=["accuracy"],
)
pixel_cnn.fit(
    x=codebook_indices,
    y=codebook_indices,
    batch_size=128,
    epochs=30,
    validation_split=0.1,
)

# %% [markdown]
# We can improve these scores with more training and hyperparameter tuning.

# %% [markdown]
# ## Codebook sampling
#
# Now that our PixelCNN is trained, we can sample distinct codes from its outputs and pass
# them to our decoder to generate novel images.

# %%
# Create a mini sampler model.
inputs = layers.Input(shape=pixel_cnn.input_shape[1:])
outputs = pixel_cnn(inputs, training=False)
categorical_layer = tfp.layers.DistributionLambda(tfp.distributions.Categorical)
outputs = categorical_layer(outputs)
sampler = keras.Model(inputs, outputs)

# %% [markdown]
# We now construct a prior to generate images. Here, we will generate 10 images.

# %%
# Create an empty array of priors.
batch = 10
priors = np.zeros(shape=(batch,) + (pixel_cnn.input_shape)[1:])
batch, rows, cols = priors.shape

# Iterate over the priors because generation has to be done sequentially pixel by pixel.
for row in range(rows):
    for col in range(cols):
        # Feed the whole array and retrieving the pixel value probabilities for the next
        # pixel.
        probs = sampler.predict(priors)
        # Use the probabilities to pick pixel values and append the values to the priors.
        priors[:, row, col] = probs[:, row, col]

print(f"Prior shape: {priors.shape}")

# %% [markdown]
# We can now use our decoder to generate the images.

# %%
# Perform an embedding lookup.
pretrained_embeddings = quantizer.embeddings
priors_ohe = tf.one_hot(priors.astype("int32"), vqvae_trainer.num_embeddings).numpy()
quantized = tf.matmul(
    priors_ohe.astype("float32"), pretrained_embeddings, transpose_b=True
)
quantized = tf.reshape(quantized, (-1, *(encoded_outputs.shape[1:])))

# Generate novel images.
decoder = vqvae_trainer.vqvae.get_layer("decoder")
generated_samples = decoder.predict(quantized)

for i in range(batch):
    plt.subplot(1, 2, 1)
    plt.imshow(priors[i])
    plt.title("Code")
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.imshow(generated_samples[i].squeeze() + 0.5)
    plt.title("Generated Sample")
    plt.axis("off")
    plt.show()

# %% [markdown]
# We can enhance the quality of these generated samples by tweaking the PixelCNN.

# %% [markdown]
# ## Additional notes
#
# * After the VQ-VAE paper was initially released, the authors developed an exponential
# moving averaging scheme to update the embeddings inside the quantizer. If you're
# interested you can check out
# [this snippet](https://github.com/deepmind/sonnet/blob/master/sonnet/python/modules/nets/vqvae.py#L124).
# * To further enhance the quality of the generated samples,
# [VQ-VAE-2](https://arxiv.org/abs/1906.00446) was proposed that follows a cascaded
# approach to learn the codebook and to generate the images.
